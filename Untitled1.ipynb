# %%
import pandas as pd

# %%
df = pd.read_csv('../../Downloads/solicitudes.csv', on_bad_lines='skip')

# %%
df
# Out:
#         id fechasolicitud                                          solicitud  \
# 0       12     2020-08-18  Bloque NHPs Septiembre 2020 : Cuadrillas Y Postes
# 1       45     2020-08-25  C-107. Proyecto Migracion equipo legacy IP. Be...
# 2       11     2020-08-18  Bloque NHPs Septiembre 2020 : Cuadrillas Y Postes
# 3       72     2020-07-22                13jul2020_ Reparaciones hub Sevilla
# 4       16     2020-08-19  SERH primera parte - LHE Arris 105 Canales (Ma...
# ...    ...            ...                                                ...
# 2907  2990     2023-01-23  PROYECTO IMPLEMENTACIÓN NUEVO CMTS_PLAYA DEL C...
# 2908  2991     2023-01-23  Solicitud de espacio y energía Kits Monitoreo ...
# 2909  2992     2023-01-23  Solicitud de espacio y energía Kits Monitoreo ...
# 2910  2993     2023-01-23  Servicio de MANTENIMIENTO CORRECTIVO a PLANTA ...
# 2911  2994     2023-01-23  Servicio de MANTENIMIENTO CORRECTIVO a PLANTA ...
#
# ...

# %%
df.set_index(['id'],inplace=True)

# %%
print(df.columns)
print('')
print(df['clienteid'].unique())
print('')
print(df['solicitanteid'].unique())
# Out:
# Index(['fechasolicitud', 'solicitud', 'clienteid', 'solicitanteid',
#        'compradorid', 'tipotrabajoid', 'estadoid', 'municipioid', 'sitioid',
#        'ot', 'solped', 'oc', 'factura', 'nr', 'estatus', 'userid', 'fecha',
#        'fechaporvalidar', 'userporvalidar', 'fechaporenviar', 'userporenviar',
#        'fechacotizada', 'usercotizada', 'fechaasignada', 'userasignada',
#        'fechaproceso', 'userproceso', 'fechaterminada', 'userterminada',
#        'fechacancelada', 'usercancelada', 'fechaot', 'userot', 'fechasolped',
#        'usersolped', 'fechaoc', 'useroc', 'fechafactura', 'userfactura',
#        'fechanr', 'usernr', 'monto', 'bitacora', 'paga', 'monedaid', 'ocurl',
#        'fechaenvrecep', 'userenvrecep', 'fechaingresado', 'useringresado',
#        'fechastdby', 'userstdby'],
#       dtype='object')
#
# [10  9  7 11 13  3 34  1 35 36 37 38 39 40 42 46 45 50]
#
# [ 18  65  13  69 115  75  43  20   9 105  77   8  21  66 104 106 107 108
# ...

# %%
df['fechafactura'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of id
# 12                      NaN
# 45                      NaN
# 11                      NaN
# 72      2020-09-08 13:15:43
# 16                      NaN
#                ...
# 2990                    NaN
# 2991                    NaN
# 2992                    NaN
# 2993                    NaN
# 2994                    NaN
# Name: fechafactura, Length: 2912, dtype: object>
